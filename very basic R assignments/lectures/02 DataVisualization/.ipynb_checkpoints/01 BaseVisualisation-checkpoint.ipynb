# %% [markdown]
# # Base R Graphics for Visualisation
# * Author: Johannes Maucher
# * Last Update: 2017-10-03, some modifications by OK in 2019
# * References:
#     - [Documentation of R graphics package](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/00Index.html)
#
#
# The functions discussed here coming from the Base R system. We will also look in another section to **ggplot()**-functions of the **tidyverse** eco-system.

# %%
library(tidyverse)
library(IRdisplay) #Loading interface to the rich display capabilities 
library(RColorBrewer)  #Loading color map 


#Resize graphics
options(repr.plot.res = 100, repr.plot.height=6, repr.plot.width=7)  #Defaults:resolution=120, width/height=7
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.0     v purrr   0.3.2
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Customer Journey Analysis
#
# `What is the Customer Journey Analysis?` It is the analysis to get the relevant touch points and their orchestration to predict and influence conversions based on marketing campaigns. It is called the "Golden standard" in marketing. Also we can define relevant attribution models based on that knowledge in Digital Analytics.
#
# <html><img src="../img/CustomerJourneyAnalysis.jpg", width=700></html>
# <font size="1">(Imagesource: J.Möller, foryouandyourcustomers, 2011)</font>

# %% [markdown]
# `Discussion:` What can we do with that knowledge according to the statement: "50% of the marketing expenses are money thrown out. But we just don't know which 50% it is"?
#
# First we only want to look to one touch point, here **Facebook**.

# %% [markdown]
# ## Facebook Ad Camaign Data
#
# According to the aboved discussion of the Customer Journey Analysis we want to visualise the data from [Facebook Ad Campaign on Kaggle](https://www.kaggle.com/madislemsalu/facebook-ad-campaign). This dataset contains data from different Facebook marketing campaigns. Some data fields with description if necessary:
#
# * 'ad_id'
# * 'reporting_start'
# * 'reporting_end'
# * 'campaign_id'
# * 'fb_campaign_id'
# * 'age'
# * 'gender'
# * 'interest1': anonymous interest1
# * 'interest2': anonymous interest2
# * 'interest3': anonymous interest3
# * 'impressions': impressions of ad
# * 'clicks': number of clicks on ad
# * 'spent': cost of ad in Facebook
# * 'total_conversion': shows the total number of signups or installs for instance
# * 'approved_conversion': tells how many became actual active users

# %%
facebookData <- read.csv(file="../data/facebook-ad-campaign.csv", header=TRUE,
                         sep=",", dec=".")

facebookData <- facebookData %>% drop_na()

glimpse(facebookData)
# Out:
# Observations: 761
# Variables: 15
# $ ad_id               <int> 708746, 708749, 708771, 708815, 708818, 708820,...
# $ reporting_start     <fct> 17/08/2017, 17/08/2017, 17/08/2017, 30/08/2017,...
# $ reporting_end       <fct> 17/08/2017, 17/08/2017, 17/08/2017, 30/08/2017,...
# $ campaign_id         <fct> 916, 916, 916, 916, 916, 916, 916, 916, 916, 91...
# $ fb_campaign_id      <fct> 103916, 103917, 103920, 103928, 103928, 103929,...
# $ age                 <fct> 30-34, 30-34, 30-34, 30-34, 30-34, 30-34, 30-34...
# $ gender              <fct> M, M, M, M, M, M, M, M, M, M, M, M, M, M, M, M,...
# $ interest1           <int> 15, 16, 20, 28, 28, 29, 15, 16, 27, 28, 31, 7, ...
# $ interest2           <int> 17, 19, 25, 32, 33, 30, 16, 20, 31, 32, 37, 8, ...
# $ interest3           <int> 17, 21, 22, 32, 32, 30, 17, 18, 31, 31, 34, 8, ...
# $ impressions         <dbl> 7350, 17861, 693, 4259, 4133, 1915, 15615, 1095...
# ...

# %% [markdown]
# ## Simple Line- and Scatterplots
# The function [`plot(x,y)`](https://www.rdocumentation.org/packages/graphics/versions/3.6.1/topics/plot) opens a window and plots the values of `y` over the values of `x`. Optionally the arguments `xlab`, `ylab` and main can be assigned in order to specify the labels on the x- and y-axis and the title, respectively.
#
# Simple linear regression is performed by the function `lm(x ~ y )`. The function returns the parameters *intercept* and *slope* of the line, which best fits to the data points, specified by their x- and y- coordinates.
#
# The function [`abline()` ](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/abline.html) adds a straight line to the plot. Here, the straight line is specified by the line-parameters (intercept and slope), which have been calculated by the linear regression function `lm`.

# %%
plot(facebookData$impressions, facebookData$clicks, 
     xlab = "impressions",
     ylab = "clicks",
     main = "Regression of clicks over impressions"
    )

regMod <- lm(facebookData$clicks ~ facebookData$impressions)
#class(regMod)
#regMod
#points(100, 2000)  #add point at (100,2000)

abline(regMod)
abline(-50, 4, col="red") #just to demonstrate how to plot lines
#title("Regression of clicks over impressions")
# Out:
# Plot with title "Regression of clicks over impressions"

# %%
head(facebookData$clicks, 100)

summary(facebookData$clicks)
# Out:
#   [1]  1  2  0  1  1  0  3  1  1  3  0  0  0  0  7  0  1  0  1  4  0  2  2  2  0
#  [26]  0  2  4  2  0  0  7 12  1  1  0 14  1  1  7  0  0  1  7  0  5  1  2  1  1
#  [51]  4  0  7  0  0  4  3  0  0  0  1  0  0  1  2  1  0  0  4  3  3  2  0  0  0
#  [76]  3  0  1  0  7  0  0  3 13  1  3  1  0  1  1 24  3  6  4  0  0  0  0  0  0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    3.00   15.34   14.00  340.00

# %% [markdown]
# ## Value-dependent filtering of dataframe rows
# Create a subset of a dataframe, by value-filtering

# %%
cat("\n#Tidyverse syntax:\n")
facebookDataRed <- facebookData %>%
        filter(impressions < 1200000) #%>%
        #select(gender, impressions, clicks) 

head(facebookDataRed, 10)
# Out:
# #Tidyverse syntax:
#    ad_id  reporting_start reporting_end campaign_id fb_campaign_id age   gender
# 1  708746 17/08/2017      17/08/2017    916         103916         30-34 M
# 2  708749 17/08/2017      17/08/2017    916         103917         30-34 M
# 3  708771 17/08/2017      17/08/2017    916         103920         30-34 M
# 4  708815 30/08/2017      30/08/2017    916         103928         30-34 M
# 5  708818 17/08/2017      17/08/2017    916         103928         30-34 M
# 6  708820 17/08/2017      17/08/2017    916         103929         30-34 M
# 7  708889 17/08/2017      17/08/2017    916         103940         30-34 M
# 8  708895 17/08/2017      17/08/2017    916         103941         30-34 M
# 9  708953 17/08/2017      17/08/2017    916         103951         30-34 M
# 10 708958 30/08/2017      30/08/2017    916         103952         30-34 M
#    interest1 interest2 interest3 impressions clicks spent total_conversion
# ...

# %% [markdown]
# <a id = 'outlierFilter'></a>
# After outlier-filtering data (see also our section "Feature Engineering") and the corresponding linear regression line shall again be plotted. The following code-cell creates a similar plot as above. However, now graphical parameters are specified. Graphical parameters define
#
#  * the size of markers: `cex`,
#  * the marker symbol: `pch`,
#  * the color of markers and lines: `col`,
#  * the type of lines: `lty`
#  * the line width: `lwd`
#
# See [Section Graphical Parameters](#graphPars) below for more details on this topic.

# %%
plot(facebookDataRed$impressions, facebookDataRed$clicks, cex=0.5, pch=0, col="blue")
abline(lm(facebookDataRed$clicks ~ facebookDataRed$impressions), col="red", lty=2)
title("Regression of clicks on inpressions")
# Out:
# Plot with title "Regression of clicks on inpressions"

# %% [markdown]
# ## Save graph to pdf, png, jpg, ...
#
# Save graph in to .pdf File with [`pdf()`](https://stat.ethz.ch/R-manual/R-devel/library/grDevices/html/pdf.html)

# %%
pdf("facebookDatagraph1.pdf")
    plot(facebookDataRed$impressions, facebookDataRed$clicks)
    abline(lm(facebookDataRed$clicks ~ facebookDataRed$impressions))
    title("Regression of clicks on inpressions") 
dev.off()
# Out:
# png
#   2

# %% [markdown]
# The graph can also be saved in other formats, by using e.g. *png(), jpeg(), tiff(), postscript()* instead of *pdf()*

# %% [markdown]
# ## Histograms
#
# Using [`hist()`](https://www.rdocumentation.org/packages/graphics/versions/3.6.1/topics/hist):

# %%
hist(facebookDataRed$impressions, freq = TRUE, breaks=20, col="blue")
# Out:
# Plot with title "Histogram of facebookDataRed$impressions"

# %% [markdown]
# ## Boxplots
#
# Using [`boxplot()`](https://www.rdocumentation.org/packages/graphics/versions/3.6.1/topics/boxplot):

# %% [markdown]
# `Keep in mind:` In the figure below you see the explanation of a boxplot in R. The minimum and maximum value are without outliers. Outliers are calculated as values which are more than 1.5 times the *Interquartile Range (IQR)* below or above the box. The Interquartile Range (IQR) is calculated as subtraction of the first quartile from the third quartile [WD17].
#
# Remember:<BR>
# 1 quartile = 0.25 quantile = 25 percentile<BR>
# 2 quartile = 0.50 quantile = 50 percentile (known as median)<BR>
# 3 quartile = 0.75 quantile = 75 percentile<BR>
# ...<BR>

# %% [markdown]
# Further explanation in section *Feature Engineering*.
#
# <html><img src="../img/boxplot1.jpg", width=600></html>
# <font size="1">(Imagesource: OK)</font>

# %%
#df <- facebookDataRed %>% filter(impressions < 200000)
#boxplot(df$impressions)

boxplot(facebookDataRed$impressions)
summary(facebookDataRed$impressions)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#      87    3104   12170   88068   83845 1194718
# plot without title

# %% [markdown]
# <a id='includeText'></a>
# ## Including Text
# Text can be included at arbitrary positions in the plot by applying the function [`text(x, y, "text")`](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/text.html). This function writes *text* at the position *x, y* in the plotting-window.
#
# Using [`abline()`](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/abline.html) to include a straight line and [`title()`](https://www.rdocumentation.org/packages/graphics/versions/3.6.1/topics/title) to create a title in the plot:

# %%
plot(facebookDataRed$impressions,facebookDataRed$clicks, cex=1.5, pch=0, 
     col="blue", type="n")
abline(lm(facebookDataRed$clicks~facebookDataRed$impressions), col="red", lty=2)

title("Regression of clicks on impressions")

text(facebookDataRed$impressions, facebookDataRed$clicks, 
     facebookDataRed$gender, cex=0.8)
# Out:
# Plot with title "Regression of clicks on impressions"

# %% [markdown]
# <a id='graphPars'></a>
# ## Graphical Parameters
#
# As already mentioned R lets you specify plotting parameters.
#
# First, a plot is generated without specifying any graphical parameters. In this case the default-parameters are applied:

# %%
year <- c(2010,2011,2012,2013,2014)
turnover <- c(2400000,3250000,2640000,4500000,4750000)
profit <- c(625000,789000,500000,810000,650000)

# %%
plot(year, turnover, ylab="turnover in Euros", xlab="Year", 
     main="Turnover of previous years")
# Out:
# Plot with title "Turnover of previous years"

# %% [markdown]
# ### Plot type
# In the example above no `type` of plot has been explicitly defined. In this case the default type, which displays points is applied. However, the `type` - argument can be used to create other representations. The possible values, which can be assigned to `type` are:
#
# Value                    |              Description
# -----------------------  | -----------------------------
# "p"	                     | Points (default)
# "l"                      | Lines
# "b"                      | Both (points and lines)
# "c"                      | for the lines part alone of "b"
# "o"                      | for both overplotted
# "h"                      | for histogram like vertical lines
# "s"                      | for stair steps
# "n"                      | for no plotting
#
# For example a stair-step representation of the data can be plotted as follows:

# %%
plot(year, turnover, type="s",  
     xlab="Year", ylab="turnover in Euros", main="Turnover of previous years")
# Out:
# Plot with title "Turnover of previous years"

# %% [markdown]
# ### Symbols and Lines
#
# Marker-symbols and -size, line-types amd -widths can be specified in plot-functions as shown already in the examples.
#
# Parameter                |              Description
# -----------------------  | -----------------------------
# pch	                     | Specifies the symbol to use when plotting points
# cex	                     | Specifies the symbol size. cex is a number indicating the amount by which plotting symbols should be scaled relative to the default. 1 = default, 1.5 is 50% larger, 0.5 is 50% smaller, and so forth.
# lty	                     | Specifies the line type
# lwd	                     | Specifies the line width. lwd is expressed relative to the default (1 = default). For example, lwd=2 generates a line twice as wide as the default.
#
# The possible values for the parameters `pch` and `lty` are shown in the pictures below:

# %%
display_png(file="../img/RgraphMarkers.PNG")

# %%
display_png(file="../img/RgraphLty.PNG")

# %% [markdown]
# ### Colors
# Colors of markers, lines, text and other graphical elements can be specified by the parameters of the following table:
#
# | Parameter |                                                                                                                  Description                                                                                                                  |
# |:---------:|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | col       | Default plotting color. Some functions (such as lines and pie) accept a vector of values that are recycled. For example, if col=c("red", "blue") and three lines are plotted, the first line will be red, the second blue, and the third red. |
# | col.axis  | color for axis text                                                                                                                                                                                                                           |
# | col.lab   | Color for axis labels                                                                                                                                                                                                                         |
# | col.main  | Color for titles                                                                                                                                                                                                                              |
# | col.sub   | Color for subtitles                                                                                                                                                                                                                           |
# | fg        | Color for plot's foreground                                                                                                                                                                                                                   |
# | bg        | Color for plot's background                                                                                                                                                                                                                   |

# %% [markdown]
# The values assigned to the parameters above can be:
#
# * index (col=1)
# * name (col="white")
# * hexadecimal (col="#FFFFFF")
# * RGB (col=rgb(1, 1, 1))
# * HSV col=hsv(0, 0, 1)
#
# All color names can be obtained as follows:

# %%
colors()
# Out:
#   [1] "white"                "aliceblue"            "antiquewhite"
#   [4] "antiquewhite1"        "antiquewhite2"        "antiquewhite3"
#   [7] "antiquewhite4"        "aquamarine"           "aquamarine1"
#  [10] "aquamarine2"          "aquamarine3"          "aquamarine4"
#  [13] "azure"                "azure1"               "azure2"
#  [16] "azure3"               "azure4"               "beige"
#  [19] "bisque"               "bisque1"              "bisque2"
#  [22] "bisque3"              "bisque4"              "black"
#  [25] "blanchedalmond"       "blue"                 "blue1"
#  [28] "blue2"                "blue3"                "blue4"
#  [31] "blueviolet"           "brown"                "brown1"
#  [34] "brown2"               "brown3"               "brown4"
#  [37] "burlywood"            "burlywood1"           "burlywood2"
#  [40] "burlywood3"           "burlywood4"           "cadetblue"
#  [43] "cadetblue1"           "cadetblue2"           "cadetblue3"
# ...

# %% [markdown]
# The mapping of indices to colors is displayed below:

# %%
display_png(file="../img/RgraphColors.PNG")

# %%
plot(year, turnover, type='b', ylab="Turnover in Euros", 
     xlab="Year", main="Turnover of previous years",
     pch=0, lty=5, col='red', col.main="blue")
# Out:
# Plot with title "Turnover of previous years"

# %%
plot(year, profit, type='o', ylab="Profit in Euros", 
     xlab="Year", main="Profit of previous years",
     pch=5, lty=6,  col=rgb(0, 1, 0), cex=0.7)
# Out:
# Plot with title "Profit of previous years"

# %% [markdown]
# #### Color palettes in R
# The following code generates `n=10` different colors of the color-palette `rainbow` and assigns this color-set to the variable `mycolors`. Then a pie-chart with `n=10` equally sized sections is plotted, each with a unique color from `mycolors`.

# %%
n <- 10
mycolors <- rainbow(n, s=0.5)
#mycolors <- topo.colors(n)
pie(rep(1, n), labels=mycolors, col=mycolors)
# Out:
# plot without title

# %% [markdown]
# Instead of *rainbow()* [other color palettes](https://stat.ethz.ch/R-manual/R-devel/library/grDevices/html/palettes.html) such as *heat.colors(), terrain.colors(), topo.colors(), cm.colors()* can be applied.
#
# Different gray levels can be generated as follows:

# %%
mygrays <- gray(0:n/n)
pie(rep(1, n), labels=mygrays, col=mygrays)
# Out:
# plot without title

# %% [markdown]
# #### Create Color Palettes with RColorBrewer

# %%
#library(RColorBrewer)
 
display.brewer.all()
# Out:
# plot without title

# %% [markdown]
# Using [`barplot`](https://www.rdocumentation.org/packages/graphics/versions/3.6.1/topics/barplot) to create a barplot:

# %%
n <- 10
mycolors <- brewer.pal(n, "Spectral")
barplot(rep(1, n), col=mycolors)
# Out:
# plot without title

# %% [markdown]
# <a id='textParams'></a>
# ### Text Parameters
# As shown in the section on [including text](#includeText) text can be plotted in graphical windows. The main graphical parameters, which allow a detailed specification of the text-form, are summarized in the tables below.
#
# | Parameter |                                                                         Description                                                                         |
# |:---------:|:-----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | cex       | Number indicating the amount by which plotted text should be scaled relative to the default. 1 = default, 1.5 is 50% larger, 0.5 is 50% smaller, and so on. |
# | cex.axis  | Size of axis text relative to cex                                                                                                                           |
# | cex.lab   | Size of axis label text relative to cex                                                                                                                     |
# | cex.main  | Size of titles relative to cex                                                                                                                              |
# | cex.sub   | Size of subtitles relative to cex                                                                                                                           |
# | pos   | Position specifier for the text. Values of 1, 2, 3 and 4, respectively indicate positions below, to the left of, above and to the right of the specified coordinates.                                                                                                                           |

# %% [markdown]
# | Parameter |                                                                   Description                                                                   |
# |:---------:|:-----------------------------------------------------------------------------------------------------------------------------------------------|
# | font      | Integer specifying the font to use for plotted text. 1 = plain, 2 = bold, 3 = italic, 4 = bold italic, and 5=symbol (in Adobe symbol encoding). |
# | font.axis | Font for axis text                                                                                                                              |
# | font.lab  | Font for axis labels                                                                                                                            |
# | font.main | Font for titles                                                                                                                                 |
# | font.sub  | Font for subtitles                                                                                                                              |
# | ps        | Font point size (roughly 1/72 inch). The text size = ps * cex                                                                                   |
# | family    | Font family for drawing text. Standard values are serif, sans and mono.                                                                         |

# %% [markdown]
# ### Access and modify default graphical parameters
# In the examples above graphical parameters have been defined within a single function call, e.g. `plot(xdata, ydata, pch=0)` or `text(x, y, "text", ces=0.7)`. If the parameters are specified in this way, they are valid only for this single function. If some parameters shall be configured permanently, e.g. the markers in all plots shall be boxes, then the `par()` function shall be applied. As shown below, the simple call of [`par()`](https://www.rdocumentation.org/packages/graphics/versions/3.3/topics/par) returns the current values of all graphical parameters:

# %%
par()
# Out:
# $xlog
# [1] FALSE
#
# $ylog
# [1] FALSE
#
# $adj
# [1] 0.5
#
# $ann
# [1] TRUE
#
# $ask
# [1] FALSE
#
# $bg
# [1] "white"
#
# $bty
# [1] "o"
#
# $cex
# [1] 1
#
# $cex.axis
# [1] 1
#
# $cex.lab
# [1] 1
#
# $cex.main
# [1] 1.2
#
# $cex.sub
# [1] 1
#
# $cin
# [1] 0.15 0.20
#
# $col
# [1] "black"
#
# $col.axis
# [1] "black"
#
# $col.lab
# [1] "black"
#
# $col.main
# [1] "black"
#
# $col.sub
# [1] "black"
#
# $cra
# [1] 10.8 14.4
#
# $crt
# [1] 0
#
# $csi
# [1] 0.2
#
# $cxy
# [1] 0.02764128 0.04143648
#
# $din
# [1] 6.666665 6.666665
#
# $err
# [1] 0
#
# $family
# [1] ""
#
# $fg
# [1] "black"
#
# $fig
# [1] 0 1 0 1
#
# $fin
# [1] 6.666665 6.666665
#
# $font
# [1] 1
#
# $font.axis
# [1] 1
#
# $font.lab
# [1] 1
#
# $font.main
# [1] 2
#
# $font.sub
# [1] 1
#
# $lab
# [1] 5 5 7
#
# $las
# [1] 0
#
# $lend
# [1] "round"
#
# $lheight
# [1] 1
#
# $ljoin
# [1] "round"
#
# $lmitre
# [1] 10
#
# $lty
# [1] "solid"
#
# $lwd
# [1] 1
#
# $mai
# [1] 1.02 0.82 0.82 0.42
#
# $mar
# [1] 5.1 4.1 4.1 2.1
#
# ...

# %% [markdown]
# As can be seen the current character size for labels and the title is `cex.lab=1` and `cex.main=1.2` respectively. The current font for labels and titles are `font.lab=1` (plain) and `font.main=2` (bold), respectively. These, and other parameters can be modified as follows:

# %%
par(font.lab=3, cex.lab=1.5, font.main=4, cex.main=2, bg="lightgray")

plot(year, turnover, type='b', ylab="Turnover in Euros", 
     xlab="Year", main="Turnover of previous years",
     pch=15, lty=5, col='red', col.main="blue")
# Out:
# Plot with title "Turnover of previous years"

# %% [markdown]
# Before we continue, we reset the graphical parameters to their original values:

# %%
par(font.lab=1, cex.lab=1.0, font.main=2, 
    cex.main=1.2, bg="white")  #reset to previous parameters

# %% [markdown]
# It is good practice to copy the original parameter values, before they are modified. This allows a comfortable restorage of the original values as shown in the following code cell:

# %%
opar <- par(no.readonly=TRUE) #make a copy of current parameters

par(pin=c(4, 3)) #modify current parameters
par(lwd=2, cex=1.5) #modify current parameters
par(cex.axis=.75, font.axis=3) #modify current parameters

plot(year, turnover, type="b", pch=19, lty=2, col="red") #plot with modified parameters

par(opar) #restore the original parameters
# Out:
# plot without title

# %% [markdown]
# ## Multiple Graphs in one figure
# As mentioned above, the `plot()`-function opens a new window and then plots the given data in the specified format. Hence each call of this function opens a new graphical window. If more graphs shall be plotted in a single window, the `plot()`-function is used for plotting the data of the first graph. For all other graphs, which shall be plotted in the same window the `lines()`-function must be applied [documentation of lines function](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/lines.html). This is demonstrated in the example below. The example also shows how to integrate a **grid** and a **legend** into a graphical window:

# %%
plot(year, turnover, type="b", pch=15, col="red", lty=1, ylim=c(0,5000000))
lines(year, profit, type="o", pch=17, lty=5, col="blue")
abline(h=1000000*(1:6), v=year, col="gray")
legend('topleft', c('turnover','profit'), pch=c(15,17), 
       col=c("red","blue"), lty=c(1,5))
# Out:
# plot without title

# %% [markdown]
# ## Arrange multiple graphical windows in a matrix
#
# Multiple graphical windows can be arranged in a grid by modifying the graphical parameter [`mfrow`](https://www.rdocumentation.org/packages/RcmdrPlugin.survival/versions/1.2-0/topics/mfrow). By default this parameter is set to `mfrow =c(1,1)`, which implies that the grid contains only one graphical window. If the parameter is modified to `mfrow= c(r,c)`, a layout grid of `r` rows and `c` columns is constructed and the following graphical windows, as generated by the `plot()`-functions, are arranged in this grid. The [`pin`](https://www.rdocumentation.org/packages/sommer/versions/4.0.1/topics/pin)-parameter is used to specify the width and height of each graphical window in the grid. E.g. with `pin=c(2, 1.5)` each window has a width of 2 inches and a height of 1.5 inches. Alternatively, the `mai`-parameter can be configured instead of the `pin`-parameter. The `mai`-parameter is a numerical vector indicating margin size `c(bottom, left, top, right)` in inches.

# %%
#Resize graphics
options(repr.plot.res = 150, repr.plot.height=7, repr.plot.width=7)  #Defaults:resolution=120, width/height=7

mycolors <- topo.colors(6)
par(mfrow=(c(2, 2)), pin=c(2, 1.5), cex=0.8, pch=16)
plot(facebookDataRed$impressions, facebookDataRed$clicks, col=mycolors[1], main="1")
plot(facebookDataRed$spent, facebookDataRed$clicks, col=mycolors[2], main="2")
plot(facebookDataRed$total_conversion, facebookDataRed$clicks, col=mycolors[3], main="3")
plot(facebookDataRed$approved_conversion, facebookDataRed$clicks, col=mycolors[4], main="4")

#Resize graphics
options(repr.plot.res = 100, repr.plot.height=7, repr.plot.width=7)  #Defaults:resolution=120, width/height=7
# Out:
# Plot with title "4"
